# %% [markdown]
# # Lab | matplotlib-seaborn

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Data

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
# There are 2 ways of doing this. Do in both ways.
# Hint: Check out the nrows, ncols, and index arguments of subplots
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way
plt.subplot(2,1,1)
plt.plot(x, y)
plt.subplot(2,1,2)
plt.plot(x ,z)

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot below

# %%
# your code here-2st way
fig, (ay, az) = plt.subplots(nrows=1, ncols=2)
ay.plot(x, y)
az.plot(x, z)

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
# Hint: Add the figsize argument in plt.subplots()

# %%
# your code here
fig, (ay, az) = plt.subplots(nrows=1, ncols=2, figsize=(8,6))
ay.plot(x, y)
az.plot(x, z)

# %% [markdown]
# #### Plot both y=x^2 and y=exp(x) in the same plot using normal and logarithmic scale.
# Hint: Use set_xscale and set_yscale

# %%
y_log = np.exp(x)
y_sq = x**2

fig, (ay, az) = plt.subplots(nrows=1, ncols=2)
ay.plot(x, y_log)
az.plot(x, y_sq)
ay.set_yscale("log")

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Import the Fitbit2.csv file and name your dataset fitbit. You can also connect to the Ironhack database to retrieve the data (db: fitbit, table: fitbit2).

# %%
# your code here
fitbit = pd.read_csv("../data/Fitbit2.csv")
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# 0               1680  ...        0.403891    Friday           4.0
# 1               2248  ...        8.767545  Saturday           5.0
# 2               1719  ...        6.567891    Sunday           6.0
# 3               9620  ...        3.119282    Monday           0.0
# 4               7360  ...        2.317714   Tuesday           1.0
#
#    Work_or_Weekend  Hours Sleep Sleep efficiency  Yesterday_sleep  \
# 0                1     6.400000        92.086331         0.000000
# 1                0     7.566667        92.464358         6.400000
# 2                0     6.450000        88.761468         7.566667
# 3                1     5.183333        88.857143         6.450000
# 4                1     6.783333        82.892057         5.183333
#
#    Yesterday_sleep_efficiency  Months  Months_encoded
# 0                    0.000000     May               5
# 1                   92.086331     May               5
# 2                   92.464358     May               5
# 3                   88.761468     May               5
# 4                   88.857143     May               5
#
# [5 rows x 24 columns]

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month?
# Is Fitbitter more active on weekend or workdays?
# All plots must be in the same jupyter notebook cell.
# Hints:
#
# Use Months_encoded and Week_or Weekend columns
# Use matplolib.pyplot object oriented API
# Set your size figure to 12,4
# Explore plt.sca
# Explore plt.xticks
# Save your figures

# %%
# Median Steps by Month_encoded
month = fitbit.groupby("Months_encoded").median()['Steps']


# Median Steps by Work_or_Weekend
week = fitbit.groupby("Work_or_Weekend").median()['Steps']

plt.subplot(2, 1, 1)
plt.plot(month)
plt.subplot(2, 1, 2)
plt.plot(week)

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# Minutes Lightly Active vs Steps
# Minutes Very Active vs Steps
# Minutes Sedentary vs Steps

# %%
# your code here
plotting=[fitbit['Minutes Lightly Active'], fitbit['Minutes Very Active'], fitbit['Minutes Sedentary']]
for i in plotting:
    plt.scatter(i, fitbit["Steps"])

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the titanic file. Name your dataset titanic. You can also connect to the Ironhack database to retrieve the data (db: titanic, table: titanic).

# %%
# your code here
titanic = pd.read_csv("../data/titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# Hint: Use Pandas select_dtypes

# %%
# your code here- numerical variable
titanic.select_dtypes(include = "number").head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
#your code here- categorical variable
titanic.select_dtypes(include = "object").head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6)
# Hint: To set the style you can use matplotlib.pyplot functions or seaborn

# %%
# your code here
plt.style.use("classic")
fig, ax = plt.subplots(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of the column Age

# %%
# your code here
sns.distplot(titanic["Age"])

# %% [markdown]
# #### Use subplots and plot the distribution of the Age variable with bins equal to 10,20 and 50.

# %%
# your code here
fig, (a10, a20, a50) = plt.subplots(nrows=1, ncols = 3, figsize=(12,6))
a10= sns.distplot(titanic["Age"], bins=10, ax=a10)
a20= sns.distplot(titanic["Age"], bins=20, ax=a20)
a50= sns.distplot(titanic["Age"], bins=50, ax=a50)

# %% [markdown]
# #### How does the bin size affect your plot? Comment.

# %% [markdown]
# #your comment here
# In the last plot it seems like we have a bimodal distribution of ages, which was not visible in the plots with less bins

# %% [markdown]
# #### Use seaborn to show the distribution of the column Age

# %% [markdown]
# Repeating action done before

# %% [markdown]
# #### Use the right plot to visualize the column Gender. There are 2 ways of doing it. Do it both ways.
# Hint: Use matplotlib and seaborn

# %%
# your code here- 1st way
#titanic1 = sns.load_dataset("titanic")
#sns.catplot(x="Gender", kind="bar", data=titanic)
#gender = titanic.groupby("Gender").count()
#gender
#sns.distplot(gender)
ax=sns.countplot(x="Gender", data=titanic)

# %%
# your code here- 2nd way
titanic["Gender"].value_counts().plot(kind='bar')

# %% [markdown]
# #### Use the right plot to visualize the column Pclass

# %%
# your code here
ax=sns.countplot(x="Pclass", data=titanic)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature Age. What kind of plot would you use?

# %%
titanic["Age"].describe()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
#your comment here
sns.boxplot(titanic["Age"])

# %% [markdown]
# #### What does the last plot tells you about the feature Age? Comment.

# %% [markdown]
# Mean age was just bellow 30 years. There were a lot of older passengers that are represented by outliers on the right.

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the SAME plot the distribution of Age. What kind of plot would you use?

# %%
#your code here
sns.violinplot(titanic["Age"])

# %% [markdown]
# #### What additional information the last plot provides you about the feature Age? Comment.

# %%
#your comment here

# %% [markdown]
# #### We suspect that there is a linear relationship between Fare and Age. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# Hint: One of the ways involves using Seaborn

# %%
#your code- 1st way
#sns.scatterplot(titanic["Fare"], titanic["Age"])
sns.lmplot(x = "Fare", y = "Age", data=titanic)

# %%
# your code-2nd way
plt.scatter(titanic["Fare"], titanic["Age"])

# %% [markdown]
# #### Using Seaborn plot the correlation matrix

# %%
#your code here
ax = sns.heatmap(titanic.corr())
#plt.matshow(titanic.corr())

# %% [markdown]
# #### What are the most correlated feature? Comment

# %% [markdown]
# #your comment here
# SibSp (Number of Siblings/Spouses Aboard) and parch (Number of Parents/Children Aboard) have
# stronger positive correlation compared to others
#
# Pclass and Fare as well as Pclass and age had stronger negative correlations than others (younger people paid less and and lower class was cheaper)

# %% [markdown]
# #### Use the right plot to display the summary statistics of the Age in function of the Pclass

# %%
#your code here
sns.boxplot(x=titanic["Pclass"], y=titanic["Age"])

# %% [markdown]
# #### Use the seaborn to plot the distribution of the Age based on the Gender
# Hint: Use Facetgrid

# %%
#your code here
grid = sns.FacetGrid(titanic, row = "Gender")
grid.map(plt.hist, "Age")
